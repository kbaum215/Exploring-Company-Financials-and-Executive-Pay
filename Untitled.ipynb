# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import csv
import requests
import os
import time
import json

# %%
main_df = pd.read_csv('execpay_financials_sp500.csv').drop(columns=['cik','id'])

main_df.drop_duplicates(inplace=True)
main_df[main_df['CEO'] == True].groupby('ticker').sum()
# Out:
#          year    salary     bonus  stockAwards  optionAwards  \
# ticker
# A       28222  14183269         0     82032760      25763923
# AAL     28222   2441140         0    130227654             0
# AAP     20165   9668318   3485000     44487383      14649081
# AAPL    24190  27321602         0     82347835             0
# ABBV    18153  14611346         0     90913929      25481828
# ...       ...       ...       ...          ...           ...
# YUM     78623  36478563   4101050     69523658      90238566
# ZBH     36306  14623693   1346000     68455584      62577128
# ZBRA    26222  12679100         0     59775901      12967242
# ZION    54431  21152988  11702000     15629354       3350878
# ZTS     20165  10643533         0     51539576      20646680
#
#         nonEquityIncentiveCompensation  otherCompensation      total  \
# ticker
# A                             19888144            1326401  145807034
# AAL                           10203331           15191967  159413533
# ...

# %%
main_df[(main_df['ticker']=='ABBV')].head(10)
# Out:
#      ticker                 name  \
# 1096   ABBV  Richard A. Gonzalez
# 1097   ABBV  Laura J. Schumacher
# 1098   ABBV    Robert A. Michael
# 1099   ABBV  Michael E. Severino
# 1100   ABBV   Jeffrey R. Stewart
# 1101   ABBV         Carlos Alban
# 1102   ABBV    Robert A. Michael
# 1103   ABBV  Richard A. Gonzalez
# 1104   ABBV  Laura J. Schumacher
# 1105   ABBV  Michael E. Severino
#
#                                                position  year   salary  bonus  \
# 1096  Chairman of the Board and Chief Executive Officer  2021  1700000      0
# 1097  Vice Chairman, External Affairs and Chief Lega...  2021  1248154      0
# 1098  Vice Chairman, Finance and Commercial Operatio...  2021  1129881      0
# 1099                        Vice Chairman and President  2021  1411031      0
# 1100  Executive Vice President, Chief Commercial Off...  2021  1074231      0
# 1101            Vice Chairman, Chief Commercial Officer  2020  1211808      0
# ...
