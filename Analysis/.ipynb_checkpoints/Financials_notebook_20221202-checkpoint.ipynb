# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import csv
import requests
import os
import time
import json
import math
import pandas as pd
from sklearn.model_selection import train_test_split
import random
import statsmodels.tools.tools as stattools
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
#List of S&P 500 tickers from: https://stockmarketmba.com/stocksinthesp500.php

ticker_list = pd.read_csv('SP500_index.csv')['Symbol']
ticker_list
# Out:
# 0       AAPL
# 1       MSFT
# 2       GOOG
# 3      GOOGL
# 4       AMZN
#        ...
# 498     LUMN
# 499      ALK
# 500      NWL
# 501      VNO
# 502      TAP
# Name: Symbol, Length: 503, dtype: object

# %%
def income_puller(ticker):
    url=f'https://stockrow.com/api/companies/{ticker}/financials.xlsx?dimension=T&section=Income%20Statement&sort=desc'
    response = requests.get(url)
    with open(os.path.join("StockRow_financials/Excel", f"{ticker}_inc.xlsx"), 'wb') as f:
        f.write(response.content)
    time.sleep(0.25)

def csv_maker(ticker):
    #this section reads the Excel file and turns into a CSV
    ticker_df = pd.read_excel(f'StockRow_financials/Excel/{ticker}_inc.xlsx').T
    # change the first row to the columns
    ticker_df.columns = ticker_df.iloc[0]
    #remove the first row
    ticker_df = ticker_df.iloc[1:]
    
    ticker_df['Ticker'] = f"{ticker}"
    
    ticker_df.to_csv(f'StockRow_financials/CSV/{ticker}_inc.csv',index_label="Date")

# %% [markdown]
# #### This code pulls financial information from StockRow.com

# %%
#do not call this function unless you have 15 minutes to kill
#also note that it overwrites all the previously downloaded Excel workbooks
#start_time = time.time()
#
#for ticker in ticker_list:
#    try:
#        income_puller(ticker)
#    except:
#        print(f"Ticker {ticker} throws an error")
#    
#print(f"Code took {np.round(time.time() - start_time,2)} seconds to run")

# %% [markdown]
# #### This code converts the StockRow workbooks from Excel files to CSV files

# %%
start_time = time.time()

for ticker in ticker_list:
    try:
        csv_maker(ticker)
    except:
        print(f"Ticker {ticker} throws an error")
    
print(f"Code took {np.round(time.time() - start_time,2)} seconds to run")
# Out:
# Ticker AAPL throws an error
# Ticker MSFT throws an error
# Ticker GOOG throws an error
# Ticker GOOGL throws an error
# Ticker AMZN throws an error
# Ticker BRK.B throws an error
# Ticker TSLA throws an error
# Ticker UNH throws an error
# Ticker XOM throws an error
# Ticker JNJ throws an error
# Ticker WMT throws an error
# Ticker V throws an error
# Ticker NVDA throws an error
# Ticker JPM throws an error
# Ticker CVX throws an error
# Ticker LLY throws an error
# Ticker PG throws an error
# Ticker MA throws an error
# Ticker HD throws an error
# Ticker META throws an error
# Ticker BAC throws an error
# Ticker PFE throws an error
# Ticker ABBV throws an error
# Ticker KO throws an error
# Ticker MRK throws an error
# Ticker PEP throws an error
# Ticker COST throws an error
# Ticker ORCL throws an error
# Ticker TMO throws an error
# Ticker AVGO throws an error
# Ticker MCD throws an error
# Ticker CSCO throws an error
# Ticker ACN throws an error
# Ticker DHR throws an error
# Ticker TMUS throws an error
# Ticker ABT throws an error
# Ticker WFC throws an error
# Ticker DIS throws an error
# Ticker NKE throws an error
# Ticker BMY throws an error
# Ticker NEE throws an error
# Ticker COP throws an error
# Ticker LIN throws an error
# Ticker VZ throws an error
# Ticker TXN throws an error
# Ticker ADBE throws an error
# Ticker AMGN throws an error
# Ticker UPS throws an error
# Ticker MS throws an error
# Ticker CRM throws an error
# Ticker CMCSA throws an error
# Ticker PM throws an error
# Ticker HON throws an error
# Ticker SCHW throws an error
# Ticker RTX throws an error
# Ticker QCOM throws an error
# Ticker T throws an error
# Ticker IBM throws an error
# Ticker NFLX throws an error
# Ticker LOW throws an error
# Ticker UNP throws an error
# Ticker GS throws an error
# Ticker CVS throws an error
# Ticker DE throws an error
# Ticker LMT throws an error
# Ticker INTC throws an error
# Ticker CAT throws an error
# Ticker AMD throws an error
# Ticker SPGI throws an error
# Ticker ELV throws an error
# Ticker AXP throws an error
# Ticker SBUX throws an error
# Ticker BLK throws an error
# Ticker INTU throws an error
# Ticker MDT throws an error
# Ticker ADP throws an error
# Ticker GILD throws an error
# Ticker PLD throws an error
# Ticker BA throws an error
# Ticker AMT throws an error
# Ticker PYPL throws an error
# Ticker CI throws an error
# Ticker C throws an error
# Ticker GE throws an error
# Ticker ISRG throws an error
# Ticker TJX throws an error
# Ticker AMAT throws an error
# Ticker MDLZ throws an error
# Ticker CB throws an error
# Ticker EOG throws an error
# Ticker ADI throws an error
# Ticker SYK throws an error
# Ticker MMC throws an error
# Ticker EL throws an error
# Ticker NOW throws an error
# Ticker NOC throws an error
# Ticker VRTX throws an error
# Ticker REGN throws an error
# Ticker MO throws an error
# Ticker BKNG throws an error
# Ticker SLB throws an error
# Ticker PGR throws an error
# Ticker TGT throws an error
# Ticker DUK throws an error
# Ticker SO throws an error
# Ticker MRNA throws an error
# Ticker MMM throws an error
# Ticker ITW throws an error
# Ticker GD throws an error
# Ticker ZTS throws an error
# Ticker HUM throws an error
# Ticker WM throws an error
# Ticker CSX throws an error
# Ticker APD throws an error
# Ticker OXY throws an error
# Ticker ETN throws an error
# Ticker HCA throws an error
# Ticker PNC throws an error
# Ticker MU throws an error
# Ticker USB throws an error
# Ticker LRCX throws an error
# Ticker CL throws an error
# Ticker BDX throws an error
# Ticker FISV throws an error
# Ticker CME throws an error
# Ticker PXD throws an error
# Ticker SHW throws an error
# Ticker AON throws an error
# Ticker BSX throws an error
# Ticker TFC throws an error
# Ticker CHTR throws an error
# Ticker EQIX throws an error
# Ticker MET throws an error
# Ticker ICE throws an error
# Ticker CCI throws an error
# Ticker ATVI throws an error
# Ticker DG throws an error
# Ticker NSC throws an error
# Ticker MPC throws an error
# Ticker EMR throws an error
# Ticker F throws an error
# Ticker GM throws an error
# Ticker KLAC throws an error
# Ticker VLO throws an error
# Ticker MCO throws an error
# Ticker KDP throws an error
# Ticker MCK throws an error
# Ticker FCX throws an error
# Ticker ADM throws an error
# Ticker ORLY throws an error
# Ticker PSX throws an error
# Ticker MNST throws an error
# Ticker PSA throws an error
# Ticker MAR throws an error
# Ticker SNPS throws an error
# Ticker D throws an error
# Ticker SRE throws an error
# Ticker GIS throws an error
# Ticker APH throws an error
# Ticker CTVA throws an error
# Ticker DVN throws an error
# Ticker ADSK throws an error
# Ticker KHC throws an error
# Ticker AZO throws an error
# Ticker CNC throws an error
# Ticker AEP throws an error
# Ticker EW throws an error
# Ticker ROP throws an error
# Ticker HSY throws an error
# Ticker CDNS throws an error
# Ticker HES throws an error
# Ticker JCI throws an error
# Ticker CTAS throws an error
# Ticker FDX throws an error
# Ticker AIG throws an error
# Ticker NXPI throws an error
# Ticker AFL throws an error
# Ticker DXCM throws an error
# Ticker BIIB throws an error
# Ticker KMB throws an error
# Ticker PAYX throws an error
# Ticker TRV throws an error
# Ticker A throws an error
# Ticker MSI throws an error
# Ticker SYY throws an error
# Ticker ENPH throws an error
# Ticker FTNT throws an error
# Ticker LHX throws an error
# Ticker ECL throws an error
# Ticker RSG throws an error
# Ticker CMG throws an error
# Ticker KMI throws an error
# Ticker MCHP throws an error
# Ticker O throws an error
# Ticker ANET throws an error
# Ticker WMB throws an error
# Ticker TT throws an error
# Ticker AJG throws an error
# Ticker PRU throws an error
# Ticker STZ throws an error
# Ticker TEL throws an error
# Ticker IQV throws an error
# Ticker MSCI throws an error
# Ticker PH throws an error
# Ticker COF throws an error
# Ticker SPG throws an error
# Ticker HLT throws an error
# Ticker EXC throws an error
# Ticker XEL throws an error
# Ticker DLTR throws an error
# Ticker NUE throws an error
# Ticker FIS throws an error
# Ticker PCAR throws an error
# Ticker CARR throws an error
# Ticker ALL throws an error
# Ticker EA throws an error
# Ticker BK throws an error
# Ticker NEM throws an error
# Ticker ILMN throws an error
# Ticker DOW throws an error
# Ticker CMI throws an error
# Ticker WBA throws an error
# Ticker YUM throws an error
# Ticker KR throws an error
# Ticker DD throws an error
# Ticker AMP throws an error
# Ticker HAL throws an error
# Ticker IDXX throws an error
# Ticker ROST throws an error
# Ticker LVS throws an error
# Ticker BF.B throws an error
# Ticker ODFL throws an error
# Ticker CSGP throws an error
# Ticker TDG throws an error
# Ticker ABC throws an error
# Ticker ALB throws an error
# Ticker ED throws an error
# Ticker OTIS throws an error
# Ticker RMD throws an error
# Ticker NDAQ throws an error
# Ticker AME throws an error
# Ticker WELL throws an error
# Ticker DLR throws an error
# Ticker SBAC throws an error
# Ticker MTD throws an error
# Ticker ON throws an error
# Ticker VICI throws an error
# Ticker CTSH throws an error
# Ticker GWW throws an error
# Ticker BKR throws an error
# Ticker PPG throws an error
# Ticker ROK throws an error
# Ticker KEYS throws an error
# Ticker HPQ throws an error
# Ticker FAST throws an error
# Ticker CEG throws an error
# Ticker WEC throws an error
# Ticker DFS throws an error
# Ticker PCG throws an error
# Ticker MTB throws an error
# Ticker APTV throws an error
# Ticker FANG throws an error
# Ticker OKE throws an error
# Ticker DHI throws an error
# Ticker GLW throws an error
# Ticker PEG throws an error
# Ticker TROW throws an error
# Ticker BAX throws an error
# Ticker STT throws an error
# Ticker ES throws an error
# Ticker LYB throws an error
# Ticker VRSK throws an error
# Ticker WBD throws an error
# Ticker GPN throws an error
# Ticker IT throws an error
# Ticker HRL throws an error
# Ticker AWK throws an error
# Ticker RJF throws an error
# Ticker GPC throws an error
# Ticker WTW throws an error
# Ticker IFF throws an error
# Ticker CDW throws an error
# Ticker EBAY throws an error
# Ticker EFX throws an error
# Ticker FITB throws an error
# Ticker LEN throws an error
# Ticker ARE throws an error
# Ticker URI throws an error
# Ticker K throws an error
# Ticker TSCO throws an error
# Ticker WY throws an error
# Ticker CBRE throws an error
# Ticker ZBH throws an error
# Ticker TSN throws an error
# Ticker FTV throws an error
# Ticker VMC throws an error
# Ticker EQR throws an error
# Ticker HIG throws an error
# Ticker AVB throws an error
# Ticker EIX throws an error
# Ticker LUV throws an error
# Ticker MKC throws an error
# Ticker ULTA throws an error
# Ticker ETR throws an error
# Ticker PFG throws an error
# Ticker FRC throws an error
# Ticker DTE throws an error
# Ticker DAL throws an error
# Ticker IR throws an error
# Ticker MLM throws an error
# Ticker AEE throws an error
# Ticker FE throws an error
# Ticker HBAN throws an error
# Ticker PWR throws an error
# Ticker ANSS throws an error
# Ticker CTRA throws an error
# Ticker ACGL throws an error
# Ticker RF throws an error
# Ticker EXR throws an error
# Ticker VRSN throws an error
# Ticker LH throws an error
# Ticker ROL throws an error
# Ticker PPL throws an error
# Ticker CAH throws an error
# Ticker CF throws an error
# Ticker HPE throws an error
# Ticker XYL throws an error
# Ticker MRO throws an error
# Ticker CFG throws an error
# Ticker EPAM throws an error
# Ticker DOV throws an error
# Ticker PAYC throws an error
# Ticker WRB throws an error
# Ticker WAT throws an error
# Ticker TDY throws an error
# Ticker NTRS throws an error
# Ticker INVH throws an error
# Ticker JBHT throws an error
# Ticker CNP throws an error
# Ticker AES throws an error
# Ticker CHD throws an error
# Ticker MOH throws an error
# Ticker CLX throws an error
# Ticker MAA throws an error
# Ticker HOLX throws an error
# Ticker WAB throws an error
# Ticker DRI throws an error
# Ticker EXPD throws an error
# Ticker MPWR throws an error
# Ticker AMCR throws an error
# Ticker J throws an error
# Ticker IEX throws an error
# Ticker KEY throws an error
# Ticker GRMN throws an error
# Ticker INCY throws an error
# Ticker VTR throws an error
# Ticker PKI throws an error
# Ticker BALL throws an error
# Ticker MOS throws an error
# Ticker CMS throws an error
# Ticker ABMD throws an error
# Ticker BR throws an error
# Ticker CAG throws an error
# Ticker TTWO throws an error
# Ticker SEDG throws an error
# Ticker FDS throws an error
# Ticker DGX throws an error
# Ticker CINF throws an error
# Ticker LYV throws an error
# Ticker STE throws an error
# Ticker WST throws an error
# Ticker FOX throws an error
# Ticker FOXA throws an error
# Ticker TRGP throws an error
# Ticker FMC throws an error
# Ticker SYF throws an error
# Ticker BRO throws an error
# Ticker NTAP throws an error
# Ticker BBY throws an error
# Ticker ATO throws an error
# Ticker OMC throws an error
# Ticker SJM throws an error
# Ticker EQT throws an error
# Ticker CPRT throws an error
# Ticker ALGN throws an error
# Ticker CPB throws an error
# Ticker APA throws an error
# Ticker HWM throws an error
# Ticker AVY throws an error
# Ticker SWKS throws an error
# Ticker COO throws an error
# Ticker IRM throws an error
# Ticker RCL throws an error
# Ticker EXPE throws an error
# Ticker GEN throws an error
# Ticker PTC throws an error
# Ticker TXT throws an error
# Ticker TER throws an error
# Ticker LDOS throws an error
# Ticker ETSY throws an error
# Ticker AKAM throws an error
# Ticker TRMB throws an error
# Ticker MGM throws an error
# Ticker LKQ throws an error
# Ticker UAL throws an error
# Ticker NVR throws an error
# Ticker FLT throws an error
# Ticker KIM throws an error
# Ticker LNT throws an error
# Ticker ESS throws an error
# Ticker JKHY throws an error
# Ticker EVRG throws an error
# Ticker TYL throws an error
# Ticker L throws an error
# Ticker VTRS throws an error
# Ticker ZBRA throws an error
# Ticker SIVB throws an error
# Ticker MTCH throws an error
# Ticker CBOE throws an error
# Ticker PEAK throws an error
# Ticker NDSN throws an error
# Ticker BEN throws an error
# Ticker TECH throws an error
# Ticker DPZ throws an error
# Ticker UDR throws an error
# Ticker HST throws an error
# Ticker IPG throws an error
# Ticker IP throws an error
# Ticker VFC throws an error
# Ticker POOL throws an error
# Ticker SNA throws an error
# Ticker RE throws an error
# Ticker CPT throws an error
# Ticker CRL throws an error
# Ticker PARA throws an error
# Ticker PKG throws an error
# Ticker LW throws an error
# Ticker SWK throws an error
# Ticker BIO throws an error
# Ticker WDC throws an error
# Ticker STX throws an error
# Ticker CHRW throws an error
# Ticker REG throws an error
# Ticker BXP throws an error
# Ticker MAS throws an error
# Ticker GL throws an error
# Ticker CE throws an error
# Ticker HSIC throws an error
# Ticker CZR throws an error
# Ticker KMX throws an error
# Ticker CCL throws an error
# Ticker NWS throws an error
# Ticker NWSA throws an error
# Ticker NI throws an error
# Ticker CDAY throws an error
# Ticker TFX throws an error
# Ticker EMN throws an error
# Ticker QRVO throws an error
# Ticker JNPR throws an error
# Ticker PHM throws an error
# Ticker ALLE throws an error
# Ticker BWA throws an error
# Ticker MKTX throws an error
# Ticker NRG throws an error
# Ticker UHS throws an error
# Ticker WRK throws an error
# Ticker CMA throws an error
# Ticker AOS throws an error
# Ticker AAL throws an error
# Ticker HII throws an error
# Ticker AAP throws an error
# Ticker BBWI throws an error
# Ticker FFIV throws an error
# Ticker WYNN throws an error
# Ticker FRT throws an error
# Ticker IVZ throws an error
# Ticker TPR throws an error
# Ticker RHI throws an error
# Ticker FBHS throws an error
# Ticker PNW throws an error
# Ticker DISH throws an error
# Ticker HAS throws an error
# Ticker WHR throws an error
# Ticker SBNY throws an error
# Ticker ZION throws an error
# Ticker CTLT throws an error
# Ticker PNR throws an error
# Ticker SEE throws an error
# Ticker RL throws an error
# Ticker NCLH throws an error
# Ticker XRAY throws an error
# Ticker DXC throws an error
# Ticker AIZ throws an error
# Ticker GNRC throws an error
# Ticker MHK throws an error
# Ticker DVA throws an error
# Ticker LNC throws an error
# Ticker OGN throws an error
# Ticker LUMN throws an error
# Ticker ALK throws an error
# Ticker NWL throws an error
# Ticker VNO throws an error
# Ticker TAP throws an error
# Code took 1.6 seconds to run

# %% [markdown]
# #### This code combines all downloaded CSV files (for which we have a ticker) into one Pandas DataFrame

# %%
starter_df = pd.read_csv(f'StockRow_financials/CSV/{ticker_list[0]}_inc.csv')

start_time = time.time()

for ticker in ticker_list[1:]:
    try:        
        ticker_df = pd.read_csv(f'StockRow_financials/CSV/{ticker}_inc.csv')
        starter_df = pd.concat([starter_df,ticker_df])
    except:
        print(f'Ticker {ticker} threw an error')
    
        
        
print(f"This code took {time.time() - start_time} seconds")
# Out:
# Ticker META threw an error
# Ticker ELV threw an error
# Ticker BALL threw an error
# Ticker TRGP threw an error
# Ticker GEN threw an error
# This code took 5.777302026748657 seconds

# %%
#save the DataFrame as one large CSV
starter_df.to_csv('SP500_allFinancials.csv',index=False)

# %% [markdown]
# #### Narrow the financial columns, convert "Date" to a DateTime object, create a "Year" field

# %%
starter_df = starter_df[['Ticker', 'Date', 'Revenue', 'Gross Profit',
                         'Operating Income', 'Income after Tax', 'Net Income Common']].reset_index(drop=True)

starter_df['Date'] = pd.to_datetime(starter_df['Date'])
starter_df['Year'] = pd.DatetimeIndex(starter_df['Date']).year

# %%
#example of grouping the data the find the average financial values for each calendar year
starter_df[starter_df['Ticker']=='AAPL'].groupby('Year').mean()
# Out:
#            Revenue  Gross Profit  Operating Income  Income after Tax  \
# Year
# 2012  1.646870e+11  6.901900e+10      5.511100e+10      4.174700e+10
# 2013  1.708525e+11  6.525800e+10      5.011225e+10      3.787200e+10
# 2014  1.841935e+11  7.101400e+10      5.336100e+10      4.005850e+10
# 2015  2.263010e+11  9.029050e+10      6.853200e+10      5.141750e+10
# 2016  2.203950e+11  8.646250e+10      6.224650e+10      4.734475e+10
# 2017  2.280935e+11  8.771550e+10      6.122750e+10      4.781425e+10
# 2018  2.574745e+11  9.855900e+10      6.820600e+10      5.710000e+10
# 2019  2.613452e+11  9.912250e+10      6.499925e+10      5.641200e+10
# 2020  2.776220e+11  1.064325e+11      6.831750e+10      5.924500e+10
# 2021  3.541752e+11  1.469285e+11      1.036732e+11      8.958700e+10
# 2022  3.892957e+11  1.686247e+11      1.190483e+11      1.004570e+11
#
#       Net Income Common
# Year
# 2012       4.174700e+10
# 2013       3.787200e+10
# 2014       4.005850e+10
# 2015       5.141750e+10
# 2016       4.734475e+10
# 2017       4.781425e+10
# 2018       5.710000e+10
# 2019       5.641200e+10
# 2020       5.924500e+10
# 2021       8.958700e+10
# 2022       1.004570e+11

# %%
#grouping the data to find average values per year for every ticker
condensed_finances_df = starter_df.groupby(['Ticker','Year']).mean()
condensed_finances_df
# Out:
#                   Revenue  Gross Profit  Operating Income  Income after Tax  \
# Ticker Year
# A      2013  6.854500e+09  3.569250e+09      9.845000e+08      9.442500e+08
#        2014  5.252250e+09  2.680750e+09      6.885000e+08      4.702500e+08
#        2015  4.619250e+09  2.308250e+09      5.257500e+08      3.070000e+08
#        2016  4.116000e+09  2.130250e+09      5.877500e+08      4.672500e+08
#        2017  4.357750e+09  2.319750e+09      7.500000e+08      6.020000e+08
# ...                   ...           ...               ...               ...
# ZTS    2018  5.644000e+09  3.819000e+09      1.673500e+09      1.166000e+09
#        2019  6.092500e+09  4.097500e+09      1.727250e+09      1.430500e+09
#        2020  6.474000e+09  4.500250e+09      1.967500e+09      1.631250e+09
#        2021  7.454000e+09  5.169500e+09      2.354000e+09      1.922500e+09
#        2022  7.964333e+09  5.451667e+09      2.553333e+09      2.074000e+09
#
#              Net Income Common
# Ticker Year
# A      2013       9.442500e+08
#        2014       6.605000e+08
#        2015       3.390000e+08
#        2016       4.650000e+08
#        2017       6.020000e+08
# ...                        ...
# ZTS    2018       1.171250e+09
#        2019       1.431000e+09
#        2020       1.632250e+09
#        2021       1.925500e+09
#        2022       2.076667e+09
#
# [5330 rows x 5 columns]

# %%
#sanity check using AAPL
condensed_finances_df.loc['AAPL']
# Out:
#            Revenue  Gross Profit  Operating Income  Income after Tax  \
# Year
# 2012  1.646870e+11  6.901900e+10      5.511100e+10      4.174700e+10
# 2013  1.708525e+11  6.525800e+10      5.011225e+10      3.787200e+10
# 2014  1.841935e+11  7.101400e+10      5.336100e+10      4.005850e+10
# 2015  2.263010e+11  9.029050e+10      6.853200e+10      5.141750e+10
# 2016  2.203950e+11  8.646250e+10      6.224650e+10      4.734475e+10
# 2017  2.280935e+11  8.771550e+10      6.122750e+10      4.781425e+10
# 2018  2.574745e+11  9.855900e+10      6.820600e+10      5.710000e+10
# 2019  2.613452e+11  9.912250e+10      6.499925e+10      5.641200e+10
# 2020  2.776220e+11  1.064325e+11      6.831750e+10      5.924500e+10
# 2021  3.541752e+11  1.469285e+11      1.036732e+11      8.958700e+10
# 2022  3.892957e+11  1.686247e+11      1.190483e+11      1.004570e+11
#
#       Net Income Common
# Year
# 2012       4.174700e+10
# 2013       3.787200e+10
# 2014       4.005850e+10
# 2015       5.141750e+10
# 2016       4.734475e+10
# 2017       4.781425e+10
# 2018       5.710000e+10
# 2019       5.641200e+10
# 2020       5.924500e+10
# 2021       8.958700e+10
# 2022       1.004570e+11

# %%
execpay_df = pd.read_csv('main_SCT_pay_file.csv')

execpay_df = execpay_df[execpay_df['ticker'].isin(ticker_list)]

execpay_df
# Out:
#                                       id      cik ticker                 name  \
# 0       73b3a60ba203743c008330c96b7d8b66  1090872      A             Sam Raha
# 1       97393f60cd9f321650e472673daaa70c  1090872      A  Michael R. McMullen
# 2       83b9cc2bca477fe8ce23e0ab56e70c66  1090872      A        Jacob Thaysen
# 3       7c60bb804071675ae15ec930f6dea190  1090872      A       Robert McMahon
# 4       259b710a8befe67c61a2c3dec14f344a  1090872      A    Padraig McDonnell
# ...                                  ...      ...    ...                  ...
# 140505  509ce14e56d662f93a33c221556bee61   829224   SBUX     Clifford Burrows
# 140509  ca5ec5821d6a445f90716a3d9695b490  1393612    DFS         Harit Talwar
# 140517  5182311313ab849b40a9a5063ec9b2da  1175454    FLT        Todd W. House
# 140520  1c4e649f102fc4f3523b36f94390bd72    14272    BMY    Anthony C. Hooper
# 140535  8a25b731a4a44ab8020d41f1beda5ba5  1175454    FLT        Todd W. House
#
#                                                  position  year   salary  \
# 0       Senior Vice President, President Diagnostics a...  2021   563500
# 1                                 Chief Executive Officer  2021  1280000
# 2       Senior Vice President, President Life Sciences...  2021   625000
# 3          Senior Vice President, Chief Financial Officer  2021   663500
# 4        Senior Vice President, President Cross-Lab Group  2021   495000
# ...                                                   ...   ...      ...
# 140505        president, Starbucks Coffee Americas and US  2011   678942
# 140509                            EVP, President—US Cards  2010  1750000
# 140517  President, US Direct Business & Chief Operatin...  2010   275000
# 140520  SVP Commercial Operations & President US, Japa...  2010   800000
# 140535  President, US Direct Business & Chief Operatin...  2009   192877
#
#          bonus  stockAwards  optionAwards  nonEquityIncentiveCompensation  \
# 0            0      1541332             0                          738536
# 1            0      9165390             0                         3149714
# 2            0      1812285             0                          897589
# 3            0      2291271             0                         1007000
# 4            0      1249771             0                          686716
# ...        ...          ...           ...                             ...
# 140505       0      2050337        909284                          633822
# 140509  875000            0          9292                               0
# 140517   40000       787500       1293779                          110000
# 140520       0      2649962             0                         1276236
# 140535   63906            0        357000                           36094
#
#         otherCompensation     total  changeInPensionValueAndDeferredEarnings  \
# 0                   33534   3262887                                      NaN
# 1                   77512  15967631                                      NaN
# 2                   13684   3802349                                      NaN
# 3                  176196   4711733                                      NaN
# 4                  499472   3243927                                      NaN
# ...                   ...       ...                                      ...
# 140505              53391   4325776                                      NaN
# 140509                  0   3531442                                  17150.0
# 140517              22487   2528766                                      0.0
# 140520             267872   6148512                                      NaN
# 140535              10679    660556                                      0.0
#
#           CEO    CFO  Interim
# 0       False  False    False
# 1        True  False    False
# 2       False  False    False
# 3       False   True    False
# 4       False  False    False
# ...       ...    ...      ...
# 140505  False  False    False
# 140509  False  False    False
# 140517  False  False    False
# 140520  False  False    False
# 140535  False  False    False
#
# [44457 rows x 17 columns]

# %%
main_df = execpay_df.merge(condensed_finances_df,left_on=['ticker','year'], right_on=['Ticker','Year'])

# %%
main_df
# Out:
#                                      id      cik ticker                 name  \
# 0      73b3a60ba203743c008330c96b7d8b66  1090872      A             Sam Raha
# 1      97393f60cd9f321650e472673daaa70c  1090872      A  Michael R. McMullen
# 2      83b9cc2bca477fe8ce23e0ab56e70c66  1090872      A        Jacob Thaysen
# 3      7c60bb804071675ae15ec930f6dea190  1090872      A       Robert McMahon
# 4      259b710a8befe67c61a2c3dec14f344a  1090872      A    Padraig McDonnell
# ...                                 ...      ...    ...                  ...
# 28435  7b803e9ff0f142d5b1c36b5fdbaced15  1564708    NWS      Gerson Zweifach
# 28436  473bf52703cdbffdc9b311d8dee9101a  1564708    NWS      Bedi Ajay Singh
# 28437  c36a1d9990a2218f8d2a09b25fb7cd65  1564708    NWS    Robert J. Thomson
# 28438  7d64a65ecf544ffd0ce4d4ada1607c73  1564708    NWS      Gerson Zweifach
# 28439  abc0667932c203c041cae8baae64f178  1564708    NWS    K. Rupert Murdoch
#
#                                                 position  year   salary  \
# 0      Senior Vice President, President Diagnostics a...  2021   563500
# 1                                Chief Executive Officer  2021  1280000
# 2      Senior Vice President, President Life Sciences...  2021   625000
# 3         Senior Vice President, Chief Financial Officer  2021   663500
# 4       Senior Vice President, President Cross-Lab Group  2021   495000
# ...                                                  ...   ...      ...
# 28435                                    General Counsel  2014  1500000
# 28436                            Chief Financial Officer  2013   655769
# 28437                            Chief Executive Officer  2013   992308
# 28438                                    General Counsel  2013        0
# 28439                                 Executive Chairman  2013        0
#
#          bonus  stockAwards  optionAwards  ...     total  \
# 0            0      1541332             0  ...   3262887
# 1            0      9165390             0  ...  15967631
# 2            0      1812285             0  ...   3802349
# 3            0      2291271             0  ...   4711733
# 4            0      1249771             0  ...   3243927
# ...        ...          ...           ...  ...       ...
# 28435        0            0             0  ...   1500000
# 28436   713425       496499             0  ...   2087442
# 28437  1000000            0             0  ...   2661463
# 28438        0            0             0  ...         0
# 28439        0            0             0  ...         0
#
#        changeInPensionValueAndDeferredEarnings    CEO    CFO  Interim  \
# 0                                          NaN  False  False    False
# 1                                          NaN   True  False    False
# 2                                          NaN  False  False    False
# 3                                          NaN  False   True    False
# 4                                          NaN  False  False    False
# ...                                        ...    ...    ...      ...
# 28435                                      NaN  False  False    False
# 28436                                      NaN  False   True    False
# 28437                                      NaN   True  False    False
# 28438                                      NaN  False  False    False
# 28439                                      NaN  False  False    False
#
#             Revenue  Gross Profit  Operating Income  Income after Tax  \
# 0      5.952000e+09  3.193250e+09      1.175500e+09      9.837500e+08
# 1      5.952000e+09  3.193250e+09      1.175500e+09      9.837500e+08
# 2      5.952000e+09  3.193250e+09      1.175500e+09      9.837500e+08
# 3      5.952000e+09  3.193250e+09      1.175500e+09      9.837500e+08
# 4      5.952000e+09  3.193250e+09      1.175500e+09      9.837500e+08
# ...             ...           ...               ...               ...
# 28435  8.548750e+09  3.453500e+09      4.040000e+08      1.545000e+08
# 28436  8.822667e+09  3.454667e+09      2.525000e+08      2.126667e+08
# 28437  8.822667e+09  3.454667e+09      2.525000e+08      2.126667e+08
# 28438  8.822667e+09  3.454667e+09      2.525000e+08      2.126667e+08
# 28439  8.822667e+09  3.454667e+09      2.525000e+08      2.126667e+08
#
#        Net Income Common
# 0            983750000.0
# 1            983750000.0
# 2            983750000.0
# 3            983750000.0
# 4            983750000.0
# ...                  ...
# 28435        -29750000.0
# 28436        169000000.0
# 28437        169000000.0
# 28438        169000000.0
# 28439        169000000.0
#
# [28440 rows x 22 columns]

# %%
main_df.ticker.value_counts()
# Out:
# A       112
# MTCH     99
# JCI      92
# APA      90
# EXC      88
#        ...
# CARR     16
# CME      14
# AMP       5
# VTRS      5
# OGN       5
# Name: ticker, Length: 485, dtype: int64

# %%
apple_df = main_df[main_df['ticker']=='AAPL']
apple_df
apple_df_2021 = apple_df[apple_df['year']==2020]
apple_df_2021
rev_2021 = apple_df_2021['Revenue']
rev_2021
# Making sure we can perform calculations with this, looking for 'float' or 'int'
type(rev_2021)

apple_df_2012 = apple_df[apple_df['year']==2012]
rev_2012 = max(apple_df_2012['Revenue'])

subtracted_rev = rev_2021-rev_2012

percent_rev_change = (subtracted_rev/rev_2012)*100

print("Revenue percentage growth over 10 years: ", percent_rev_change)
# Out:
# Revenue percentage growth over 10 years:  117    68.57554
# 118    68.57554
# 119    68.57554
# 120    68.57554
# 121    68.57554
# Name: Revenue, dtype: float64

# %%
main_df_ticker_list = main_df['ticker'].unique()
main_df_ticker_list
data_2012 = []
# data_2013 = []
# data_2014 = []
# data_2015 = []
# data_2016 = []
# data_2017 = []
# data_2018 = []
# data_2019 = []
# data_2020 = []
data_2021 = []
data_change_dollars = []
data_change_percentage = []


data = {"Ticker": main_df_ticker_list,
       "Revenue 2012": data_2012,
#         "Revenue 2013": data_2013,
#         "Revenue 2014": data_2014,
#         "Revenue 2015": data_2015,
#         "Revenue 2016": data_2016,
#        "Revenue 2017": data_2017,
#         "Revenue 2018": data_2018,
#         "Revenue 2019": data_2019,
#         "Revenue 2020": data_2020,
        "Revenue 2021": data_2021,
       "Revenue Change $": data_change_dollars,
       "Revenue Change %": data_change_percentage}

for ticker in main_df_ticker_list:
    ticker_df = main_df[main_df["ticker"]==ticker]
    try:
        ticker_df_2012 = ticker_df[ticker_df["year"]==2012]
        rev_2012 = max(ticker_df_2012["Revenue"])
        data_2012.append(rev_2012)
    except:
        data_2012.append("No Data Available")
#     try:
#         ticker_df_2013 = ticker_df[ticker_df["year"]==2013]
#         rev_2013 = max(ticker_df_2013["Revenue"])
#         data_2013.append(rev_2013)
#     except:
#         data_2013.append("No Data Available")
#     try:
#         ticker_df_2014 = ticker_df[ticker_df["year"]==2014]
#         rev_2014 = max(ticker_df_2014["Revenue"])
#         data_2014.append(rev_2014)
#     except:
#         data_2014.append("No Data Available")
#     try:
#         ticker_df_2015 = ticker_df[ticker_df["year"]==2015]
#         rev_2015 = max(ticker_df_2015["Revenue"])
#         data_2015.append(rev_2015)
#     except:
#         data_2015.append("No Data Available")
#     try:
#         ticker_df_2016 = ticker_df[ticker_df["year"]==2016]
#         rev_2016 = max(ticker_df_2016["Revenue"])
#         data_2016.append(rev_2016)
#     except:
#         data_2016.append("No Data Available")
#     try:
#         ticker_df_2017 = ticker_df[ticker_df["year"]==2017]
#         rev_2017 = max(ticker_df_2017["Revenue"])
#         data_2017.append(rev_2017)
#     except:
#         data_2017.append("No Data Available")
#     try:
#         ticker_df_2018 = ticker_df[ticker_df["year"]==2018]
#         rev_2018 = max(ticker_df_2018["Revenue"])
#         data_2018.append(rev_2018)
#     except:
#         data_2018.append("No Data Available")    
#     try:
#         ticker_df_2019 = ticker_df[ticker_df["year"]==2019]
#         rev_2019 = max(ticker_df_2019["Revenue"])
#         data_2019.append(rev_2019)
#     except:
#         data_2019.append("No Data Available")
#     try:
#         ticker_df_2020 = ticker_df[ticker_df["year"]==2020]
#         rev_2020 = max(ticker_df_2020["Revenue"])
#         data_2020.append(rev_2020)
#     except:
#         data_2020.append("No Data Available")
    try:
        ticker_df_2021 = ticker_df[ticker_df['year']==2021]
        rev_2021 = max(ticker_df_2021['Revenue'])
        data_2021.append(rev_2021)
    except:
        data_2021.append("No Data Available")
    try:
        rev_change_dollars = rev_2021 - rev_2012
        data_change_dollars.append(rev_change_dollars)
    except:
        print("No calculation performed")
    try:
        rev_change_percentage = (rev_change_dollars / rev_2012)*100
        data_change_percentage.append(rev_change_percentage)
    except:
        print("No calculation performed")
        
        

new_df = pd.DataFrame(data, index = main_df_ticker_list)
new_df
no_data_2012 = new_df["Revenue 2012"] == "No Data Available" 
no_data_2021 = new_df["Revenue 2021"] == "No Data Available"
no_calc_2012 = new_df.loc[no_data_2012, ["Revenue Change $", "Revenue Change %"]] = "No Calculation Performed"
no_calc_2022 = new_df.loc[no_data_2021, ["Revenue Change $", "Revenue Change %"]] = "No Calculation Performed"
print(new_df.head(15))
print(new_df.shape)
# Out:
#       Ticker         Revenue 2012         Revenue 2021  \
# A          A    No Data Available         5952000000.0
# AAPL    AAPL       164687000000.0       354175250000.0
# MSFT    MSFT        72930000000.0       172302750000.0
# AMZN    AMZN        61093000000.0  447553750000.000061
# TSLA    TSLA          413256000.0        44618250000.0
# GOOGL  GOOGL    No Data Available    No Data Available
# GOOG    GOOG        46039000000.0       228366750000.0
# UNH      UNH       110618000000.0       275483250000.0
# JNJ      JNJ        67224000000.0        89659750000.0
# XOM      XOM  480681000000.000122    No Data Available
# JPM      JPM       108074000000.0       127989000000.0
# NVDA    NVDA    No Data Available        20525500000.0
# PG        PG        81646000000.0        76618000000.0
# V          V        10720000000.0        23395750000.0
# CVX      CVX       241909000000.0       129147500000.0
#
#                Revenue Change $          Revenue Change %
# A      No Calculation Performed  No Calculation Performed
# AAPL             189488250000.0                115.059628
# MSFT              99372750000.0                136.257713
# AMZN        386460750000.000061                632.577791
# TSLA              44204994000.0              10696.757942
# GOOGL  No Calculation Performed  No Calculation Performed
# GOOG             182327750000.0                 396.02891
# UNH              164865250000.0                149.040165
# JNJ               22435750000.0                 33.374613
# XOM    No Calculation Performed  No Calculation Performed
# JPM               19915000000.0                 18.427189
# NVDA   No Calculation Performed  No Calculation Performed
# PG                -5028000000.0                 -6.158293
# V                 12675750000.0                118.243937
# CVX             -112761500000.0                -46.613189
# (485, 5)

# %% [markdown]
# The following code block shows that we have 84 of our 485 companies that do not have data in either 2021 or 2012. Some have both that are missing but overall, we can see that 2012 is the bigger culprit of missing revenue data.

# %%
print(f"Missing {new_df['Revenue 2012'].value_counts()['No Data Available']} values in 2012")
print(f"Missing {new_df['Revenue 2021'].value_counts()['No Data Available']} values in 2021")
print(f"Missing {new_df['Revenue Change $'].value_counts()['No Calculation Performed']} change history records overall")
# Out:
# Missing 73 values in 2012
# Missing 14 values in 2021
# Missing 84 change history records overall

# %%
index_no_calc = new_df[new_df['Revenue Change $'] == 'No Calculation Performed'].index
new_df.drop(index_no_calc , inplace=True)
new_df
# print(new_df_filtered.head(15))
# print(new_df_filtered.shape)
# Out:
#      Ticker    Revenue 2012         Revenue 2021     Revenue Change $  \
# AAPL   AAPL  164687000000.0       354175250000.0       189488250000.0
# MSFT   MSFT   72930000000.0       172302750000.0        99372750000.0
# AMZN   AMZN   61093000000.0  447553750000.000061  386460750000.000061
# TSLA   TSLA     413256000.0        44618250000.0        44204994000.0
# GOOG   GOOG   46039000000.0       228366750000.0       182327750000.0
# ...     ...             ...                  ...                  ...
# ALK     ALK    4657000000.0         4455250000.0         -201750000.0
# DVA     DVA    8186280000.0        11573402000.0         3387122000.0
# VNO     VNO    2649217100.0         1524119500.0        -1125097600.0
# DISH   DISH   13181334000.0        17680414750.0         4499080750.0
# RL       RL    6924400000.0         5318200000.0        -1606200000.0
#
#      Revenue Change %
# AAPL       115.059628
# MSFT       136.257713
# AMZN       632.577791
# TSLA     10696.757942
# GOOG        396.02891
# ...               ...
# ALK         -4.332188
# DVA         41.375594
# VNO         -42.46906
# DISH        34.132211
# RL         -23.196234
#
# [401 rows x 5 columns]

# %%
# Performing a rank on who grew the most and least, by percentage growth not overall growth
new_df['Growth_Rank'] = new_df['Revenue Change %'].rank(ascending=False)
new_df

# Sorting the rank
rslt_df = new_df.sort_values(by = 'Growth_Rank')
# There are three rows with NaN for 2021 Revenue data to drop
rslt_df = rslt_df.dropna()

# %%
rslt_df.head(30)
# Out:
#      Ticker   Revenue 2012         Revenue 2021     Revenue Change $  \
# TSLA   TSLA    413256000.0        44618250000.0        44204994000.0
# FANG   FANG     74962000.0         4948250000.0         4873288000.0
# DXCM   DXCM     99900000.0         2241049950.0         2141149950.0
# NOW     NOW    243712000.0         5357500000.0         5113788000.0
# CNC     CNC   8110000000.0       120285750000.0       112175750000.0
# INCY   INCY    297059000.0         2830670425.0         2533611425.0
# REGN   REGN   1378477100.0        12799075000.0        11420597900.0
# NFLX   NFLX   3609281800.0        28076899750.0        24467617950.0
# EPAM   EPAM    433799000.0         3239886500.0         2806087500.0
# AMZN   AMZN  61093000000.0  447553750000.000061  386460750000.000061
# CBOE   CBOE    512338000.0         3483075150.0         2970737150.0
# CHTR   CHTR   7504000000.0        50411000000.0        42907000000.0
# ALGN   ALGN    560041000.0         3499667425.0         2939626425.0
# ABMD   ABMD    151794000.0          939890500.0          788096500.0
# LEN     LEN   4105132000.0        25099789500.0        20994657500.0
# CI       CI  29119000000.0       168514000000.0       139395000000.0
# FTNT   FTNT    533639000.0         3026574925.0         2492935925.0
# DHI     DHI   4722500000.0        26726099000.0        22003599000.0
# SIVB   SIVB    984264100.0         5356748000.0         4372483900.0
# ZBRA   ZBRA    996168000.0         5249750000.0         4253582000.0
# CSGP   CSGP    349936000.0         1839697325.0         1489761325.0
# ENPH   ENPH    216678000.0         1137001250.0          920323250.0
# ICE     ICE   1363000000.0         7075250000.0         5712250000.0
# MPWR   MPWR    213813000.0         1071375250.0          857562250.0
# GOOG   GOOG  46039000000.0       228366750000.0       182327750000.0
# TMUS   TMUS  15961590000.0        79039250000.0        63077660000.0
# LRCX   LRCX   3168549000.0        15038472000.0        11869923000.0
# VRTX   VRTX   1527042000.0         6950734500.0         5423692500.0
# MOH     MOH   5914209000.0        24585500000.0        18671291000.0
# MCHP   MCHP   1490390000.0         5904900000.0         4414510000.0
#
#      Revenue Change %  Growth_Rank
# TSLA     10696.757942          1.0
# FANG      6501.011179          2.0
# DXCM      2143.293243          3.0
# NOW       2098.291426          4.0
# CNC       1383.178175          5.0
# INCY       852.898389          6.0
# REGN       828.493843          7.0
# NFLX       677.908218          8.0
# EPAM       646.863524          9.0
# AMZN       632.577791         10.0
# CBOE       579.839315         11.0
# CHTR        571.78838         12.0
# ALGN        524.89486         13.0
# ABMD       519.188176         14.0
# LEN        511.424663         15.0
# CI          478.70806         16.0
# FTNT       467.157746         17.0
# DHI        465.931159         18.0
# SIVB       444.238889         19.0
# ZBRA       426.994443         20.0
# CSGP        425.72394         21.0
# ENPH        424.74236         22.0
# ICE         419.09391         23.0
# MPWR         401.0805         24.0
# GOOG        396.02891         25.0
# TMUS       395.184064         26.0
# LRCX       374.616993         27.0
# VRTX        355.17638         28.0
# MOH        315.702252         29.0
# MCHP       296.198311         30.0

# %%
rslt_df[rslt_df['Revenue Change %']< 0].count()
# Out:
# Ticker              70
# Revenue 2012        70
# Revenue 2021        70
# Revenue Change $    70
# Revenue Change %    70
# Growth_Rank         70
# dtype: int64

# %%
print(f"Median of Percent Revenue Change is {rslt_df['Revenue Change %'].median()}")
print(f"Mean of Percent Revenue Change is {rslt_df['Revenue Change %'].mean()}")
# Out:
# Median of Percent Revenue Change is 52.98032445273718
# Mean of Percent Revenue Change is 148.36562357985858

# %%
rslt_df['Label'] = ['Growing Company' if x >= 0
                    else 'Declining Company' 
                    for x in rslt_df['Revenue Change %']]
rslt_df['Label'].value_counts()
# Out:
# Growing Company      328
# Declining Company     70
# Name: Label, dtype: int64

# %%
main_df.head(15)
main_df = main_df.drop_duplicates()
main_df.loc[main_df['ticker']=='A']
# Out:
#                                    id      cik ticker                   name  \
# 0    73b3a60ba203743c008330c96b7d8b66  1090872      A               Sam Raha
# 1    97393f60cd9f321650e472673daaa70c  1090872      A    Michael R. McMullen
# 2    83b9cc2bca477fe8ce23e0ab56e70c66  1090872      A          Jacob Thaysen
# 3    7c60bb804071675ae15ec930f6dea190  1090872      A         Robert McMahon
# 4    259b710a8befe67c61a2c3dec14f344a  1090872      A      Padraig McDonnell
# 10   6a9fd7caafd5ff9409e40f8c289e1cd3  1090872      A          Jacob Thaysen
# 11   ccef820f858971ef639e1266f4b96840  1090872      A    Michael R. McMullen
# 12   0afb57350eef3b644a4f9802490ce25f  1090872      A         Robert McMahon
# 13   5c5621b65ca11ff037e274c80b191cd2  1090872      A               Sam Raha
# 14   4deeb4d5b673e6f653a86a1eddda5990  1090872      A         Genomics Group
# 15   9637116a014dc78e135a1d65a0831e78  1090872      A              Mark Doak
# 22   e22445c4e02f5347b2e40cbee5789855  1090872      A    Michael R. McMullen
# 23   ca8648d0544fa3180a6edc2d02a14c82  1090872      A         Robert McMahon
# 24   56ef5c9c8b7f5e16ed1c7b2fe79b59d6  1090872      A         Genomics Group
# 25   d41442da4b3801c2139f69932b802b1e  1090872      A              Mark Doak
# 26   93f8d0fe6316e6a144439bc3c141bc9d  1090872      A          Jacob Thaysen
# 27   8830ad897377808bae9e8833e0265300  1090872      A           Michael Tang
# 34   55f648eec48f4dcede4ca6a5994f0481  1090872      A          Jacob Thaysen
# 35   392901ea2763dd2e201a44dde00f7da9  1090872      A         Robert McMahon
# 36   99164580887f667c5d56319a065a07e1  1090872      A    Michael R. McMullen
# 37   93f6834cefea5c3dc174d07a9d617864  1090872      A        Human Resources
# 38   8da1e032270355f6a9421f9c86c78437  1090872      A              Mark Doak
# 39   a8ee964000ed2eb96c1e9cee384182e8  1090872      A         Dominique Grau
# 46   e048daf0786cf01a1b260e2d48fc6b99  1090872      A        Human Resources
# 47   2a318ae1fb2ac866af17486e49563820  1090872      A    Michael R. McMullen
# 48   b846615fbe785357bd5a5c48b468696f  1090872      A     Patrick Kaltenbach
# 49   9d5fef9b9e9e99e038903c1255f80895  1090872      A          Didier Hirsch
# 50   8f0626122dd54a0ed7e4dde3d5181b14  1090872      A              Mark Doak
# 51   16f1ec86b31b1ebced16e98aa3b3b71d  1090872      A          Jacob Thaysen
# 58   a13b28e1a078d7d7abcbaa143b74bc66  1090872      A          Didier Hirsch
# 59   afeb892081434400721bc17149de2de4  1090872      A          Jacob Thaysen
# 60   2d37dac047db8fd03cfcacfe73d701a3  1090872      A  Applied Markets Group
# 61   365622904851a1079530120efd7db657  1090872      A        Human Resources
# 62   6e525b30af9d2f4e44b7c1d67f072833  1090872      A    Michael R. McMullen
# 63   ece95b49afb2267f963e22254bb3749d  1090872      A              Mark Doak
# 64   733eaae28284cb81dd47193f5edf955f  1090872      A     Patrick Kaltenbach
# 72   bd787dd65f1458a8a34a4d8eb1edf173  1090872      A     Patrick Kaltenbach
# 73   88ba9193971115c64b4b338c80ae2369  1090872      A          Didier Hirsch
# 74   73bacd1b846e148680eb4a9becc62344  1090872      A                  Chain
# 75   1fa34d6f5935e9de3d36e3fa398b8ce3  1090872      A    Michael R. McMullen
# 76   8338bde68a45b23cb89207f7f0ca48ad  1090872      A              Mark Doak
# 77   e96906309e246a7c5bb160c798988614  1090872      A                  Group
# 84   05a042698e63b1f1d6e5e326c5791dfd  1090872      A          Didier Hirsch
# 85   605f6d5e14e301ffec5c6ba2041d28b4  1090872      A         Marie Oh Huber
# 86   74d8234da776693b7fb0888c50653825  1090872      A    Michael R. McMullen
# 87   d3af951ba9570439f8e44affe16bc27f  1090872      A    Ronald S. Nersesian
# 88   56fe7f35486e52fd83e1dded8482b048  1090872      A                  Group
# 89   a6ad6be0d2312415b499e2961d5f1589  1090872      A    William P. Sullivan
# 96   649b6806fbe4a654140ba6e0aa7c2c25  1090872      A                  Group
# 97   b4add3c41ed5c86ed22bfce5309856fa  1090872      A          Didier Hirsch
# 98   5ce6068d033adac551087700211e1918  1090872      A    Designate, Keysight
# 99   9bd549134abbd8a364e660c272f6daa7  1090872      A    Michael R. McMullen
# 100  4ca37fb051392e805eb9d6436b55eb75  1090872      A    William P. Sullivan
# 101  494a3f0983f34c1b769175d70f229d69  1090872      A        and Diagnostics
# 102  c4d72990c76de80b5f428196ad9686b9  1090872      A         Lars Holmkvist
# 103  8f98917e1baf986ed5115bcf8041b331  1090872      A    Ronald S. Nersesian
#
#                                               position  year   salary  \
# 0    Senior Vice President, President Diagnostics a...  2021   563500
# 1                              Chief Executive Officer  2021  1280000
# 2    Senior Vice President, President Life Sciences...  2021   625000
# 3       Senior Vice President, Chief Financial Officer  2021   663500
# 4     Senior Vice President, President Cross-Lab Group  2021   495000
# 10   Senior Vice President, President Life Sciences...  2020   614904
# 11                             Chief Executive Officer  2020  1172853
# 12      Senior Vice President, Chief Financial Officer  2020   638333
# 13    Senior Vice President, President Diagnostics and  2020   538782
# 14   Michael Tang Senior Vice President, General Co...  2020   561026
# 15   Senior Vice President, President Agilent Cross...  2020   316538
# 22                             Chief Executive Officer  2019  1220833
# 23      Senior Vice President, Chief Financial Officer  2019   610000
# 24   Michael Tang Senior Vice President, General Co...  2019   545833
# 25   Senior Vice President, President Agilent Cross...  2019   597917
# 26   Senior Vice President, President Life Sciences...  2019   597917
# 27              Senior Vice President, General Counsel  2019   545833
# 34   Senior Vice President, President Life Sciences...  2018   556250
# 35      Senior Vice President, Chief Financial Officer  2018   147879
# 36                             Chief Executive Officer  2018  1168750
# 37   Didier Hirsch Former Senior Vice President, Ch...  2018   648333
# 38    Senior Vice President, President Cross-Lab Group  2018   570833
# 39                              Senior Vice President,  2018   470625
# 46   Didier Hirsch Former Senior Vice President, Ch...  2017   627500
# 47                             Chief Executive Officer  2017  1095833
# 48   Senior Vice President, President Life Sciences...  2017   532083
# 49      Senior Vice President, Chief Financial Officer  2017   627500
# 50    Senior Vice President, President Cross-Lab Group  2017   520833
# 51    Senior Vice President, President Diagnostics and  2017   495000
# 58      Senior Vice President, Chief Financial Officer  2016   600000
# 59    Senior Vice President, President Diagnostics and  2016   436667
# 60   Jacob Thaysen Senior Vice President, President...  2016   436667
# 61   Didier Hirsch Former Senior Vice President, Ch...  2016   600000
# 62                             Chief Executive Officer  2016  1041667
# 63   Senior Vice President, President Cross-Labs Group  2016   470833
# 64   Senior Vice President, President Life Sciences...  2016   487976
# 72   Senior Vice President, President Life Sciences...  2015   407262
# 73      Senior Vice President, Chief Financial Officer  2015   600000
# 74   Patrick Kaltenbach Senior Vice President, Pres...  2015   407262
# 75                   President Chief Executive Officer  2015   845833
# 76         Senior Vice President, President Cross-Labs  2015   422917
# 77   William P. Sullivan Former President and Chief...  2015   630000
# 84      Senior Vice President, Chief Financial Officer  2014   600000
# 85   Senior Vice President, General Counsel and Sec...  2014   525000
# 86               President and Chief Operating Officer  2014   606250
# 87   Executive Vice President and Keysight Presiden...  2014   795833
# 88   William P. Sullivan Former President and Chief...  2014  1050000
# 89                             Chief Executive Officer  2014  1050000
# 96   William P. Sullivan Former President and Chief...  2013  1045000
# 97      Senior Vice President, Chief Financial Officer  2013   597917
# 98   Nicolas Roelofs Former Senior Vice President, ...  2013   550000
# 99               President and Chief Operating Officer  2013   575000
# 100              President and Chief Executive Officer  2013  1045000
# 101  Michael R. McMullen Senior Vice President, Che...  2013   575000
# 102        Former Senior Vice President, Life Sciences  2013   938588
# 103  Executive Vice President and President and Chi...  2013   741667
#
#        bonus  stockAwards  optionAwards  ...     total  \
# 0          0      1541332             0  ...   3262887
# 1          0      9165390             0  ...  15967631
# 2          0      1812285             0  ...   3802349
# 3          0      2291271             0  ...   4711733
# 4          0      1249771             0  ...   3243927
# 10         0      2117779             0  ...   3074102
# 11         0     11190749             0  ...  13610481
# 12         0      2614535             0  ...   3665071
# 13         0      1673282             0  ...   2471060
# 14         0      1568688             0  ...   2439705
# 15    500000      2614535             0  ...   3643380
# 22         0      9560588             0  ...  12520566
# 23   1000000      2221067             0  ...   4379242
# 24         0      1351856             0  ...   2343354
# 25         0      2240337             0  ...   3428935
# 26         0      1858905             0  ...   2897546
# 27         0      1351856             0  ...   2343354
# 34         0      1845713             0  ...   3015792
# 35   2000000      4131798             0  ...   6581863
# 36         0      8476147             0  ...  11708230
# 37         0      2808278             0  ...   4172419
# 38         0      2088406             0  ...   3321646
# 39         0      1276453             0  ...   2212764
# 46         0      2676250             0  ...   3940597
# 47         0      7205347             0  ...  10090661
# 48         0      1787948             0  ...   3546852
# 49         0      2676250             0  ...   3940597
# 50         0      1899068             0  ...   2925510
# 51         0      1338104             0  ...   2400930
# 58         0      2747816             0  ...   3932395
# 59         0       845472             0  ...   2813641
# 60         0       845472             0  ...   2813641
# 61         0      2747816             0  ...   3932395
# 62         0      6341255             0  ...   8914415
# 63         0      1638114             0  ...   2640208
# 64         0      1479571             0  ...   4394271
# 72         0       505138        481253  ...   2651077
# 73         0      1049012       1001660  ...   3296798
# 74         0       505138        481253  ...   2651077
# 75         0      2520205       2434524  ...   7207852
# 76         0       549457        524676  ...   1965087
# 77         0      3057116       1946094  ...   6467847
# 84         0      1044826       1048187  ...   3453842
# 85         0      1007380        752534  ...   2905708
# 86         0      2332309        994432  ...   4530940
# 87         0      2109864       2257639  ...   6259851
# 88         0      6632830       4569033  ...  13914733
# 89         0      6632830       4569033  ...  13914733
# 96         0      3789936       4141200  ...  10235672
# 97         0       869456        950040  ...   2932127
# 98         0       668802        730800  ...   4338332
# 99         0       802571        876960  ...   2856840
# 100        0      3789936       4141200  ...  10235672
# 101        0       802571        876960  ...   2856840
# 102        0       891721             0  ...   2894007
# 103        0      1560567       1705200  ...   4758690
#
#      changeInPensionValueAndDeferredEarnings    CEO    CFO  Interim  \
# 0                                        NaN  False  False    False
# 1                                        NaN   True  False    False
# 2                                        NaN  False  False    False
# 3                                        NaN  False   True    False
# 4                                        NaN  False  False    False
# 10                                       NaN  False  False    False
# 11                                       NaN   True  False    False
# 12                                       NaN  False   True    False
# 13                                       NaN  False  False    False
# 14                                       NaN  False  False    False
# 15                                       NaN  False  False    False
# 22                                       0.0   True  False    False
# 23                                       0.0  False   True    False
# 24                                       NaN  False  False    False
# 25                                       0.0  False  False    False
# 26                                       0.0  False  False    False
# 27                                       0.0  False  False    False
# 34                                       NaN  False  False    False
# 35                                       NaN  False   True    False
# 36                                       NaN   True  False    False
# 37                                       NaN  False   True    False
# 38                                       NaN  False  False    False
# 39                                       NaN  False  False    False
# 46                                       NaN  False   True    False
# 47                                       NaN   True  False    False
# 48                                       NaN  False  False    False
# 49                                       NaN  False   True    False
# 50                                       NaN  False  False    False
# 51                                       NaN  False  False    False
# 58                                       NaN  False   True    False
# 59                                       NaN  False  False    False
# 60                                       NaN  False  False    False
# 61                                       NaN  False   True    False
# 62                                       NaN   True  False    False
# 63                                       NaN  False  False    False
# 64                                       NaN  False  False    False
# 72                                       NaN  False  False    False
# 73                                       NaN  False   True    False
# 74                                       NaN  False  False    False
# 75                                       NaN   True  False    False
# 76                                       NaN  False  False    False
# 77                                       NaN   True  False    False
# 84                                  111158.0  False   True    False
# 85                                   96907.0  False  False    False
# 86                                   91716.0  False  False    False
# 87                                  148366.0   True  False    False
# 88                                       NaN   True  False    False
# 89                                       0.0   True  False    False
# 96                                       NaN   True  False    False
# 97                                  110862.0  False   True    False
# 98                                   85248.0  False  False    False
# 99                                  106498.0  False  False    False
# 100                                      0.0   True  False    False
# 101                                 106498.0  False  False    False
# 102                                      0.0  False  False    False
# 103                                 138164.0   True  False    False
#
#           Revenue  Gross Profit  Operating Income  Income after Tax  \
# 0    5.952000e+09  3.193250e+09      1.175500e+09      9.837500e+08
# 1    5.952000e+09  3.193250e+09      1.175500e+09      9.837500e+08
# 2    5.952000e+09  3.193250e+09      1.175500e+09      9.837500e+08
# 3    5.952000e+09  3.193250e+09      1.175500e+09      9.837500e+08
# 4    5.952000e+09  3.193250e+09      1.175500e+09      9.837500e+08
# 10   5.258500e+09  2.813250e+09      8.352500e+08      7.142500e+08
# 11   5.258500e+09  2.813250e+09      8.352500e+08      7.142500e+08
# 12   5.258500e+09  2.813250e+09      8.352500e+08      7.142500e+08
# 13   5.258500e+09  2.813250e+09      8.352500e+08      7.142500e+08
# 14   5.258500e+09  2.813250e+09      8.352500e+08      7.142500e+08
# 15   5.258500e+09  2.813250e+09      8.352500e+08      7.142500e+08
# 22   5.064750e+09  2.760250e+09      9.330000e+08      1.100000e+09
# 23   5.064750e+09  2.760250e+09      9.330000e+08      1.100000e+09
# 24   5.064750e+09  2.760250e+09      9.330000e+08      1.100000e+09
# 25   5.064750e+09  2.760250e+09      9.330000e+08      1.100000e+09
# 26   5.064750e+09  2.760250e+09      9.330000e+08      1.100000e+09
# 27   5.064750e+09  2.760250e+09      9.330000e+08      1.100000e+09
# 34   4.764750e+09  2.582500e+09      8.580000e+08      2.617500e+08
# 35   4.764750e+09  2.582500e+09      8.580000e+08      2.617500e+08
# 36   4.764750e+09  2.582500e+09      8.580000e+08      2.617500e+08
# 37   4.764750e+09  2.582500e+09      8.580000e+08      2.617500e+08
# 38   4.764750e+09  2.582500e+09      8.580000e+08      2.617500e+08
# 39   4.764750e+09  2.582500e+09      8.580000e+08      2.617500e+08
# 46   4.357750e+09  2.319750e+09      7.500000e+08      6.020000e+08
# 47   4.357750e+09  2.319750e+09      7.500000e+08      6.020000e+08
# 48   4.357750e+09  2.319750e+09      7.500000e+08      6.020000e+08
# 49   4.357750e+09  2.319750e+09      7.500000e+08      6.020000e+08
# 50   4.357750e+09  2.319750e+09      7.500000e+08      6.020000e+08
# 51   4.357750e+09  2.319750e+09      7.500000e+08      6.020000e+08
# 58   4.116000e+09  2.130250e+09      5.877500e+08      4.672500e+08
# 59   4.116000e+09  2.130250e+09      5.877500e+08      4.672500e+08
# 60   4.116000e+09  2.130250e+09      5.877500e+08      4.672500e+08
# 61   4.116000e+09  2.130250e+09      5.877500e+08      4.672500e+08
# 62   4.116000e+09  2.130250e+09      5.877500e+08      4.672500e+08
# 63   4.116000e+09  2.130250e+09      5.877500e+08      4.672500e+08
# 64   4.116000e+09  2.130250e+09      5.877500e+08      4.672500e+08
# 72   4.619250e+09  2.308250e+09      5.257500e+08      3.070000e+08
# 73   4.619250e+09  2.308250e+09      5.257500e+08      3.070000e+08
# 74   4.619250e+09  2.308250e+09      5.257500e+08      3.070000e+08
# 75   4.619250e+09  2.308250e+09      5.257500e+08      3.070000e+08
# 76   4.619250e+09  2.308250e+09      5.257500e+08      3.070000e+08
# 77   4.619250e+09  2.308250e+09      5.257500e+08      3.070000e+08
# 84   5.252250e+09  2.680750e+09      6.885000e+08      4.702500e+08
# 85   5.252250e+09  2.680750e+09      6.885000e+08      4.702500e+08
# 86   5.252250e+09  2.680750e+09      6.885000e+08      4.702500e+08
# 87   5.252250e+09  2.680750e+09      6.885000e+08      4.702500e+08
# 88   5.252250e+09  2.680750e+09      6.885000e+08      4.702500e+08
# 89   5.252250e+09  2.680750e+09      6.885000e+08      4.702500e+08
# 96   6.854500e+09  3.569250e+09      9.845000e+08      9.442500e+08
# 97   6.854500e+09  3.569250e+09      9.845000e+08      9.442500e+08
# 98   6.854500e+09  3.569250e+09      9.845000e+08      9.442500e+08
# 99   6.854500e+09  3.569250e+09      9.845000e+08      9.442500e+08
# 100  6.854500e+09  3.569250e+09      9.845000e+08      9.442500e+08
# 101  6.854500e+09  3.569250e+09      9.845000e+08      9.442500e+08
# 102  6.854500e+09  3.569250e+09      9.845000e+08      9.442500e+08
# 103  6.854500e+09  3.569250e+09      9.845000e+08      9.442500e+08
#
#      Net Income Common
# 0         9.837500e+08
# 1         9.837500e+08
# 2         9.837500e+08
# 3         9.837500e+08
# 4         9.837500e+08
# 10        7.142500e+08
# 11        7.142500e+08
# 12        7.142500e+08
# 13        7.142500e+08
# 14        7.142500e+08
# 15        7.142500e+08
# 22        1.100000e+09
# 23        1.100000e+09
# 24        1.100000e+09
# 25        1.100000e+09
# 26        1.100000e+09
# 27        1.100000e+09
# 34        2.617500e+08
# 35        2.617500e+08
# 36        2.617500e+08
# 37        2.617500e+08
# 38        2.617500e+08
# 39        2.617500e+08
# 46        6.020000e+08
# 47        6.020000e+08
# 48        6.020000e+08
# 49        6.020000e+08
# 50        6.020000e+08
# 51        6.020000e+08
# 58        4.650000e+08
# 59        4.650000e+08
# 60        4.650000e+08
# 61        4.650000e+08
# 62        4.650000e+08
# 63        4.650000e+08
# 64        4.650000e+08
# 72        3.390000e+08
# 73        3.390000e+08
# 74        3.390000e+08
# 75        3.390000e+08
# 76        3.390000e+08
# 77        3.390000e+08
# 84        6.605000e+08
# 85        6.605000e+08
# 86        6.605000e+08
# 87        6.605000e+08
# 88        6.605000e+08
# 89        6.605000e+08
# 96        9.442500e+08
# 97        9.442500e+08
# 98        9.442500e+08
# 99        9.442500e+08
# 100       9.442500e+08
# 101       9.442500e+08
# 102       9.442500e+08
# 103       9.442500e+08
#
# [56 rows x 22 columns]

# %%
# Need to drop duplicate Agilent ones with the name "Group" or "human resources"
indexAge = main_df[ (main_df['name'] == 'Group') | 
                   (main_df['name'] == 'Human Resources') ].index
main_df.drop(indexAge , inplace=True)
df_CEO = main_df[(main_df['CEO'] == True)] 
df_CFO = main_df[(main_df['CFO'] == True)] 

df_CEO = df_CEO.groupby('ticker').sum()
df_CFO = df_CFO.groupby('ticker').sum()

# Subsetting for the fields we want
df_CEO = df_CEO[['CEO','salary', 'bonus', 'stockAwards', 
                 'optionAwards','nonEquityIncentiveCompensation', 
                 'total', 'Revenue', 'Net Income Common']]
df_CEO.loc[df_CEO["CEO"] > 0, "CEO"] = True

df_CFO = df_CFO[['CEO','salary', 'bonus', 'stockAwards', 
                 'optionAwards','nonEquityIncentiveCompensation', 
                 'total', 'Revenue', 'Net Income Common']]
df_CFO.loc[df_CFO["CEO"] == 0, "CEO"] = False
df_CFO
# Out:
# /var/folders/z6/8mnnwqqs4ygbtn13wtcl9q_80000gn/T/ipykernel_64751/555004581.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main_df.drop(indexAge , inplace=True)
#           CEO    salary    bonus  stockAwards  optionAwards  \
# ticker
# A       False   5085129  3000000     19646031       2999887
# AAL     False   7218184        0     38471191             0
# AAP     False   6083854   980000     11459057       2125173
# AAPL    False  10355499        0    224247705             0
# ABBV    False   8307776        0     28358014       7884662
# ...       ...       ...      ...          ...           ...
# YUM     False   7267423  1214000     12410093      12570321
# ZBH         5   8256718  2240321     22413931      20588689
# ZBRA    False   7106988        0     13943450       3185978
# ZION    False   6419692  3652500      5839982        985436
# ZTS     False   7704090  2600000     18872778       7109989
#
#         nonEquityIncentiveCompensation      total       Revenue  \
# ticker
# A                              4580051   36893668  4.623975e+10
# AAL                           11200278   62707472  4.588178e+11
# AAP                            3206254   25343797  1.189908e+11
# AAPL                          31428755  266979198  2.529333e+12
# ABBV                          15018849   78579417  2.689395e+11
# ...                                ...        ...           ...
# YUM                            9141876   49258979  9.790075e+10
# ZBH                            7456420   64576959  9.811212e+10
# ZBRA                           7189476   31782137  5.131666e+10
# ZION                           1808345   17642731  2.865551e+10
# ZTS                            6657597   45597108  8.033900e+10
#
#         Net Income Common
# ticker
# A            6.070500e+09
# AAL          1.355525e+10
# AAP          6.034603e+09
# AAPL         5.686565e+11
# ABBV         4.946950e+10
# ...                   ...
# YUM          1.473400e+10
# ZBH          8.603825e+09
# ZBRA         3.526936e+09
# ZION         5.211822e+09
# ZTS          1.365375e+10
#
# [484 rows x 9 columns]

# %%
frames = [df_CEO, df_CFO]
  
new_main = pd.concat(frames)
new_main = new_main.sort_values(by=['ticker'])
new_main['salary/revenue'] = new_main.salary / new_main.Revenue
salary_column = new_main.pop('salary/revenue')
new_main.insert(2, 'salary/revenue', salary_column)

new_main['bonus/revenue'] = new_main.bonus / new_main.Revenue
bonus_column = new_main.pop('bonus/revenue')
new_main.insert(4, 'bonus/revenue', bonus_column)

new_main['stockAwards/revenue'] = new_main.stockAwards / new_main.Revenue
stockAwards_column = new_main.pop('stockAwards/revenue')
new_main.insert(6, 'stockAwards/revenue', stockAwards_column)

new_main['optionAwards/revenue'] = new_main.optionAwards / new_main.Revenue
optionAwards_column = new_main.pop('optionAwards/revenue')
new_main.insert(8, 'optionAwards/revenue', optionAwards_column)

new_main['nonEquityIncentiveCompensation/revenue'] = new_main.nonEquityIncentiveCompensation / new_main.Revenue
nonEquityIncentiveCompensation_column = new_main.pop('nonEquityIncentiveCompensation/revenue')
new_main.insert(10, 'nonEquityIncentiveCompensation/revenue', 
                nonEquityIncentiveCompensation_column)

# Dropping Where CEO is not equal to True or False
indexNumbers = new_main[ (new_main['CEO'] == 3) | 
                 (new_main['CEO'] == 2) | (new_main['CEO'] == 5)].index
new_main.drop(indexNumbers , inplace=True)

# Converting True/False CEO column from object to boolean because the model
# was not recognizing the y-predictor type.
new_main['CEO'] = new_main['CEO'].astype(bool)
print(new_main.dtypes)
new_main
# Out:
# CEO                                          bool
# salary                                      int64
# salary/revenue                            float64
# bonus                                       int64
# bonus/revenue                             float64
# stockAwards                                 int64
# stockAwards/revenue                       float64
# optionAwards                                int64
# optionAwards/revenue                      float64
# nonEquityIncentiveCompensation              int64
# nonEquityIncentiveCompensation/revenue    float64
# total                                       int64
# Revenue                                   float64
# Net Income Common                         float64
# dtype: object
#           CEO    salary  salary/revenue     bonus  bonus/revenue  stockAwards  \
# ticker
# A        True  11458269        0.000196         0       0.000000     68552878
# A       False   5085129        0.000110   3000000       0.000065     19646031
# AAL      True   2441140        0.000005         0       0.000000    130227654
# AAL     False   7218184        0.000016         0       0.000000     38471191
# AAP      True   9668318        0.000107   3485000       0.000039     44487383
# ...       ...       ...             ...       ...            ...          ...
# ZBRA     True  12679100        0.000285         0       0.000000     59775901
# ZION    False   6419692        0.000224   3652500       0.000127      5839982
# ZION     True  21152988        0.000300  11702000       0.000166     15629354
# ZTS      True  10643533        0.000198         0       0.000000     51539576
# ZTS     False   7704090        0.000096   2600000       0.000032     18872778
#
#         stockAwards/revenue  optionAwards  optionAwards/revenue  \
# ticker
# A                  0.001175      15107596              0.000259
# A                  0.000425       2999887              0.000065
# AAL                0.000269             0              0.000000
# AAL                0.000084             0              0.000000
# AAP                0.000492      14649081              0.000162
# ...                     ...           ...                   ...
# ZBRA               0.001344      12967242              0.000292
# ZION               0.000204        985436              0.000034
# ZION               0.000222       3350878              0.000048
# ZTS                0.000956      20646680              0.000383
# ZTS                0.000235       7109989              0.000088
#
#         nonEquityIncentiveCompensation  \
# ticker
# A                             16133895
# A                              4580051
# AAL                           10203331
# AAL                           11200278
# AAP                            8633582
# ...                                ...
# ZBRA                          19148913
# ZION                           1808345
# ZION                           7071579
# ZTS                           16059793
# ZTS                            6657597
#
#         nonEquityIncentiveCompensation/revenue      total       Revenue  \
# ticker
# A                                     0.000277  115188782  5.834650e+10
# A                                     0.000099   36893668  4.623975e+10
# AAL                                   0.000021  159413533  4.842888e+11
# AAL                                   0.000024   62707472  4.588178e+11
# AAP                                   0.000095   83061159  9.050150e+10
# ...                                        ...        ...           ...
# ZBRA                                  0.000431  105531711  4.446959e+10
# ZION                                  0.000063   17642731  2.865551e+10
# ZION                                  0.000100   58692242  7.047798e+10
# ZTS                                   0.000298  101710673  5.388575e+10
# ZTS                                   0.000083   45597108  8.033900e+10
#
#         Net Income Common
# ticker
# A            7.675250e+09
# A            6.070500e+09
# AAL          1.304125e+10
# AAL          1.355525e+10
# AAP          4.663842e+09
# ...                   ...
# ZBRA         3.304858e+09
# ZION         5.211822e+09
# ZION         1.245729e+10
# ZTS          9.552250e+09
# ZTS          1.365375e+10
#
# [959 rows x 14 columns]

# %% [markdown]
# Given that we have a small data set here, I am going to go off the guidance of the book in partitioning. "On the other hand, for smaller or less complex data sets, one should retain sufficient records for accurate assessment, so that the training sets would contain only 50–67% of the original data." I think we should sufficient records to train on though, so I posit that we do a 60% training, 40% testing split (if you think we should do otherwise, by all means I am all ears).

# %%
#Partitioning the data
fin_train, fin_test = train_test_split(new_main, 
                                       test_size = 0.4, random_state = 7)

# Testing to see if we have partitioned correctly.
print("Shape of entire dataset: ",new_main.shape,"\n")
print("Value counts of CEO vs CFO:\n",new_main['CEO'].value_counts(),"\n")
print("Shape of training dataset: ",fin_train.shape,"\n")
print("Shape of testing dataset: ",fin_test.shape)
# Out:
# Shape of entire dataset:  (959, 14)
#
# Value counts of CEO vs CFO:
#  True     497
# False    462
# Name: CEO, dtype: int64
#
# Shape of training dataset:  (575, 14)
#
# Shape of testing dataset:  (384, 14)

# %% [markdown]
# Baseline model: We call the "positive" class "True" for CEO and see that a baseline model would predict correctly with (497/959) = 52% accuracy. If our model beats 52% accuracy, then it beats the baseline and is considered useful. I am not going to choose the X variables as proportions of revenue, although I can see there being multicollinearity concerns with this approach if we are incorporating the Y variable into the X variable in this way. I am curious to hear your thoughts on this. Note that I am not taking the "total comp" as this would definitely be a multicollinearity concern if we are using the other 5 variables.

# %%
# CART Model
y = fin_train[['CEO']]
X = fin_train[['salary/revenue','bonus/revenue','stockAwards/revenue','optionAwards/revenue',
              'nonEquityIncentiveCompensation/revenue']]
cart01 = DecisionTreeClassifier(criterion = "gini", max_leaf_nodes=5).fit(X,y)
predCart = cart01.predict(X)

# Setting up the variables from the test dataset.
y_test = fin_test['CEO']
X_test = fin_test[['salary/revenue','bonus/revenue','stockAwards/revenue','optionAwards/revenue',
              'nonEquityIncentiveCompensation/revenue']]

predCart_test = cart01.predict(X_test)
data_crosstab_cart = pd.crosstab(y_test,
                            predCart_test, 
                            rownames=['Actual'], 
                            colnames=['Prediction'],
                            margins = False)
print(data_crosstab_cart)
# Out:
# Prediction  False  True
# Actual
# False         117    74
# True           41   152

# %%
#C5.0 Model
c50_01 = DecisionTreeClassifier(criterion="entropy", max_leaf_nodes=5).fit(X,y)
predC5 = c50_01.predict(X)

predC5_test = c50_01.predict(X_test)
data_crosstab_C5 = pd.crosstab(y_test,
                            predC5_test, 
                            rownames=['Actual'], 
                            colnames=['Prediction'],
                            margins = False)
print(data_crosstab_C5)
# Out:
# Prediction  False  True
# Actual
# False         121    70
# True           49   144

# %%
#Random Forest Model
rfy = np.ravel(y)
rf01 = RandomForestClassifier(n_estimators = 100, criterion="gini").fit(X,rfy)
predRf = rf01.predict(X)

predRf_test = rf01.predict(X_test)
data_crosstab_RF = pd.crosstab(y_test,
                            predRf_test, 
                            rownames=['Actual'], 
                            colnames=['Prediction'],
                            margins = False)
print(data_crosstab_RF)
# Out:
# Prediction  False  True
# Actual
# False         137    54
# True           43   150

# %%
# main_df.to_csv('execpay_financials_sp500.csv',index=False)
