# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# %%
df = pd.read_csv('./datasets/main_SCT_pay_file.csv')
df.head()
# Out:
#                                  id      cik ticker                 name  \
# 0  73b3a60ba203743c008330c96b7d8b66  1090872      A             Sam Raha
# 1  97393f60cd9f321650e472673daaa70c  1090872      A  Michael R. McMullen
# 2  83b9cc2bca477fe8ce23e0ab56e70c66  1090872      A        Jacob Thaysen
# 3  7c60bb804071675ae15ec930f6dea190  1090872      A       Robert McMahon
# 4  259b710a8befe67c61a2c3dec14f344a  1090872      A    Padraig McDonnell
#
#                                             position  year   salary  bonus  \
# 0  Senior Vice President, President Diagnostics a...  2021   563500      0
# 1                            Chief Executive Officer  2021  1280000      0
# 2  Senior Vice President, President Life Sciences...  2021   625000      0
# 3     Senior Vice President, Chief Financial Officer  2021   663500      0
# 4   Senior Vice President, President Cross-Lab Group  2021   495000      0
#
#    stockAwards  optionAwards  nonEquityIncentiveCompensation  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172774 entries, 0 to 172773
# Data columns (total 17 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   id                                       172774 non-null  object
#  1   cik                                      172774 non-null  int64
#  2   ticker                                   172774 non-null  object
#  3   name                                     172723 non-null  object
#  4   position                                 169375 non-null  object
#  5   year                                     172774 non-null  int64
#  6   salary                                   172774 non-null  int64
#  7   bonus                                    172774 non-null  int64
#  8   stockAwards                              172774 non-null  int64
#  9   optionAwards                             172774 non-null  int64
# ...

# %%
df.describe()
# Out:
#                 cik           year        salary         bonus   stockAwards  \
# count  1.727740e+05  172774.000000  1.727740e+05  1.727740e+05  1.727740e+05
# mean   9.079633e+05    2014.198415  4.813634e+05  9.318964e+05  1.493095e+06
# std    5.091578e+05       4.545459  3.671945e+05  1.499217e+08  5.594280e+07
# min    1.750000e+03    2004.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    7.231250e+05    2010.000000  2.880000e+05  0.000000e+00  0.000000e+00
# 50%    9.409420e+05    2015.000000  4.129455e+05  0.000000e+00  3.378220e+05
# 75%    1.307954e+06    2018.000000  6.000000e+05  9.001500e+03  1.170596e+06
# max    1.915657e+06    2022.000000  2.000000e+07  5.232056e+10  1.798045e+10
#
#        optionAwards  nonEquityIncentiveCompensation  otherCompensation  \
# count  1.727740e+05                    1.727740e+05       1.727740e+05
# mean   1.425116e+06                    9.668322e+05       4.410965e+05
# ...

# %%
#Dropping the 212 duplicates
df.duplicated().sum()
df_deduped = df.drop_duplicates()
df_deduped.duplicated().sum()
# Out:
# 0

# %%
#Unique values of ticker
df_deduped.ticker.value_counts()
# Out:
# DCOM    162
# JCI     159
# OFIX    155
# ESI     145
# ES      142
#        ...
# PMTS      1
# RSLS      1
# UEPS      1
# LBY       1
# SIAL      1
# Name: ticker, Length: 2606, dtype: int64

# %%
#Unique values of cik
df_deduped.cik.value_counts()
# Out:
# 884624     155
# 827052     139
# 1109357    138
# 1054905    137
# 828944     137
#           ...
# 1659323      1
# 1208208      1
# 1056386      1
# 902274       1
# 938113       1
# Name: cik, Length: 2767, dtype: int64

# %%
#Unique values of year
df_deduped.year.value_counts()
# Out:
# 2020    13170
# 2019    13116
# 2018    12444
# 2021    12208
# 2017    12019
# 2016    11561
# 2015    11183
# 2014    10912
# 2013    10530
# 2012    10107
# 2011     9857
# 2008     9719
# 2010     9622
# 2009     9517
# 2007     9308
# 2006     6275
# 2022      787
# 2005      223
# 2004        4
# Name: year, dtype: int64

# %%
#How many CEOs do we have
df_deduped.CEO.value_counts()
# Out:
# False    134064
# True      38498
# Name: CEO, dtype: int64

# %%
df_deduped.CFO.value_counts()
# Out:
# False    138527
# True      34035
# Name: CFO, dtype: int64
